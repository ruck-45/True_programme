# %% [markdown]
# # KNN Regression

# %% [markdown]
# - Here the model also considers the neighbors depending on the K value we have set
# - But Since it is a regression analysis, the prediction is the mean of the K nearest Neighbours.

# %% [markdown]
# ![image.png](attachment:image.png)
